# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.arange(-10,10,0.1)
def sigmoid(x):
    ans = []
    for i in x:
        y=1/(1+np.exp(-i))
        ans.append(y)
    return ans
plt.plot(x,sigmoid(x))
plt.xlim(-6,6)
plt.ylim(0,1)
plt.show()

# %%
sigmoid(x)
# Out:
# [4.5397868702434395e-05,
#  5.0172164683764205e-05,
#  5.5448524722794907e-05,
#  6.127973961660237e-05,
#  6.772414961977011e-05,
#  7.48462275106111e-05,
#  8.271722285166624e-05,
#  9.141587385216126e-05,
#  0.00010102919390777254,
#  0.00011165334062956235,
#  0.0001233945759862313,
#  0.00013637032707949654,
#  0.00015071035805975686,
#  0.0001665580647773352,
#  0.00018407190496342303,
#  0.00020342697805520542,
#  0.0002248167702332941,
#  0.00024845508183933296,
#  0.00027457815610133096,
#  0.00030344703002891705,
#  0.0003353501304664757,
#  0.0003706061406263939,
#  0.0004095671649860472,
#  0.0004526222232405314,
#  0.0005002011070795599,
#  0.0005527786369235946,
#  0.0006108793594343956,
#  0.0006750827306328316,
#  0.0007460288338366896,
#  0.0008244246863982865,
#  0.0009110511944006356,
#  0.001006770820085626,
#  0.0011125360328603088,
#  0.001229398621277406,
#  0.0013585199504289425,
#  0.0015011822567369728,
#  0.0016588010801744009,
#  0.0018329389424927812,
# ...
